# %% [markdown]
# # Tinyflux: Example with fictious temperature readings created through an LLM

# %%
import csv
from tinyflux import TinyFlux, Point, FieldQuery, TagQuery, TimeQuery, MeasurementQuery
from datetime import datetime, timezone, timedelta

# %% [markdown]
# ## Initialize the TinyFlux database

# %%
db = TinyFlux("random_temperature_Data.db")

# %% [markdown]
# ## Writing a CSV file into Tinyflux (directly, without exporting to a Python DataFrame first)

# %%
# Read CSV and insert data into TinyFlux
with open("example_data/tinyflux_time_series_dataset_with_tags.csv", mode="r") as file:
    ###  more="r" steht für "read-only mode"
    reader = csv.DictReader(file)
    for row in reader:
    ### hier wird tatsächlich in einem Loop jede Zeile einzeln abgehandelt, deswegen dauert das auch so lange    
        px = Point(
            time=datetime.strptime(row["timestamp"], "%Y-%m-%d %H:%M:%S"),
            ### this is a specific python method und steht für "string parse time" (parse time saved as string to time)
            ### das "%" im Zeitformat Platzhalter dient als "padding", quasi für leading-zero 
            measurement="weather",
            fields={"temperature": float(row["temperature"])},  # Only numeric fields
            tags={
                ### numerical data is not supported in tags, for that a second measurement would need to be created
                "condition": row["weather_condition"],  # Move non-numeric fields to tags
                "landscape_type": row["location"]
            }
        )
        db.insert(px)

# %%
### test des Inserts oben, gem. Übungsaufgabe sollen die ersten 10 Zeilen ausgegeben werden. TinyFlux scheint
### aber keine Methode zu haben, die Query auf N Einträge zu limitieren

measurement = MeasurementQuery()
results = db.search(measurement == "weather")

# Get the first N entries in the "results" array
for x in results[:10]:
    print(x)
# Out:
# Point(time=2020-01-01T00:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:rural, fields=temperature:22.483570765056164)
# Point(time=2020-01-01T00:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:rural, fields=temperature:22.483570765056164)
# Point(time=2020-01-01T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:19.308678494144075)
# Point(time=2020-01-01T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:19.308678494144075)
# Point(time=2020-01-01T02:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.23844269050346)
# Point(time=2020-01-01T02:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.23844269050346)
# Point(time=2020-01-01T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:rural, fields=temperature:27.61514928204013)
# Point(time=2020-01-01T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:rural, fields=temperature:27.61514928204013)
# Point(time=2020-01-01T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:rural, fields=temperature:18.829233126383322)
# Point(time=2020-01-01T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:rural, fields=temperature:18.829233126383322)

# %% [markdown]
# ## Writing manually into Tinyflux

# %%
# Create manual records
### the measurements are missing, all these new entry are recorded but with measurement "default"
### because this codeblock ran multuple times, data data is duplicated. Should the "primary key" not have prevented this?

p1 = Point(
    time=datetime(2024, 9, 29, 15, 0, tzinfo=timezone.utc),
    tags={"landscape_type": "suburb", "condition": "overcast"},
    fields={"temperature": 16.5}
)

p2 = Point(
    time=datetime(2024, 9, 29, 16, 0, tzinfo=timezone.utc),
    tags={"landscape_type": "suburb", "condition": "rainy"},
    fields={"temperature": 17.3}
)

p3 = Point(
    time=datetime(2024, 9, 29, 14, 0, tzinfo=timezone.utc),
    tags={"landscape_type": "suburb", "condition": "rainy"},
    fields={"temperature": 15.7}
)


p4 = Point(
    time=datetime(2024, 9, 29, 13, 0, tzinfo=timezone.utc),
    tags={"landscape_type": "suburb", "condition": "rainy"},
    fields={"temperature": 14.9}
)

p5 = Point(
    time=datetime(2024, 9, 29, 11, 0, tzinfo=timezone.utc),
    tags={"landscape_type": "suburb", "condition": "cloudy"},
    fields={"temperature": 13.8}
)
### in the previous block it was part of a loop, here it could be done with an array:
### db.insert([p1,p2])
db.insert(p1)
db.insert(p2)
db.insert(p3)
db.insert(p4)
db.insert(p5)
# Out:
# 1

# %% [markdown]
# ## Querying by Time

# %%
# Search for a time value
Time = TimeQuery()
time_start = Time >= datetime(2024, 1, 1, tzinfo=timezone.utc)
time_end = Time < datetime(2024, 12, 31, tzinfo=timezone.utc)
time_count = db.count(time_start & time_end)
print("Time Query Count:")
print(time_count)

### thats correct, the dataset is from 2020 and I only have 2 measurements from 2024
# Out:
# Time Query Count:
# 11

# %% [markdown]
# ## Querying by Field

# %%
# Search for a field value
### I do not understand these 2 lines at all
Field = FieldQuery()
field_results = db.select("fields.temperature", Field.temperature > 15.00)
print("\nField Query Results:")
### the \n designates a new line
for x in field_results:
    print(x)
# Out:
# Field Query Results:
# 22.483570765056164
# 19.308678494144075
# 23.23844269050346
# 27.61514928204013
# 18.829233126383322
# 18.8293152152541
# 27.896064077536955
# 23.837173645764544
# 17.65262807032524
# 22.712800217929825
# 17.682911535937688
# 17.671351232148716
# 21.20981135783017
# 17.188562353795135
# 21.571236662976368
# 15.459879622393945
# 27.32824384460777
# 18.871118497567323
# 20.33764102343962
# 17.278086377374088
# 20.55461294854933
# 21.87849009172836
# 16.996806550405974
# 18.541531251033618
# 16.991466938853016
# 29.261390922544688
# 19.93251387631033
# 24.112724560515943
# 21.044317975023777
# 20.984306179345616
# 23.692332899977053
# 20.85684140594985
# 19.421758588058797
# 18.494481522053555
# 16.400778958026457
# 17.696806145201062
# 25.285611131094576
# 21.71809144784231
# 21.620419846973974
# 18.074588597918417
# 16.615389998470206
# 23.05838144420434
# 25.154997612479754
# 24.656400595580994
# 15.803912383886807
# 18.453938120743928
# 21.65631715701782
# 24.877725635611796
# 17.60412881077355
# 19.071705116680914
# 24.062629111970992
# 26.781200142854114
# 19.63994939209833
# 25.01766448946012
# 21.80818012523817
# 16.77440122697438
# 21.80697802754207
# 27.690182832329846
# 19.820869804450243
# 27.82321827907003
# 24.10951252187612
# 20.435235341190857
# 18.504963247670663
# 20.45880388267751
# 18.90164056081244
# 21.78556285755873
# 27.38947022370758
# 17.40864890863176
# 15.957531985534061
# 17.491214782077318
# 24.57701058851037
# 21.643755548298422
# 17.351198981164806
# 22.56633716556678
# 20.4853877467402
# 24.843224952664446
# 16.489734530613237
# 18.361689267011158
# 18.039459234339212
# 21.48060138532288
# 21.305276360899448
# 20.025567283212304
# 18.827064333124266
# 17.896773386173205
# 18.286427417366152
# 15.988613653891905
# 19.193571441669953
# 22.020254284072692
# 29.43092950605265
# 20.872889064159196
# 21.28775195361382
# 19.627770421169163
# 19.867430622753915
# 20.301151049705133
# 32.316210562426434
# 19.038195176094387
# 21.507736711668063
# 19.826441151473784
# 25.714114072575104
# 23.759665163433873
# 23.955159735215233
# 15.453062726026305
# 27.013971554680495
# 22.934285469001352
# 30.952278129049894
# 16.81306436346741
# 25.94508265553776
# 27.102521239949276
# 17.14626853125262
# 15.838222134478857
# 22.35707778193202
# 17.238884778595143
# 23.164659088777555
# 21.0146151042565
# 27.737526006650306
# 28.97938836547761
# 16.93605654757807
# 18.061492200320078
# 21.429326953624525
# 21.672283949935125
# 23.29272136336415
# 30.051022693831747
# 19.11526386252975
# 16.00851377730773
# 16.345349800290403
# 19.834365135631014
# 28.97278931758894
# 17.411943504819142
# 21.118939758194493
# 19.91788551963624
# 25.94196636724042
# 32.63466212936811
# 17.345656135398396
# 17.55280278740889
# 25.22080438534536
# 23.40945744813156
# 29.23353662868017
# 22.919640926629818
# 18.203539546064704
# 22.953274153461546
# 25.543517902914537
# 24.102410905986822
# 22.53637015553649
# 25.333373447945768
# 25.846477952228362
# 26.910794955187637
# 23.243549437948214
# 19.164409598415727
# 20.733568432166614
# 26.032544832541785
# 15.91532164506382
# 21.843366544364507
# 18.033305938363196
# 20.143724114674086
# 26.392259313036494
# 20.955495340099517
# 20.232182740780743
# 23.731267830136105
# 23.227420905705376
# 30.8162736165273
# 18.461108825234994
# 21.095751638319694
# 21.246918418553776
# 27.887266398817374
# 19.523522338065238
# 21.395107628851697
# 23.039482548582697
# 20.93304561578179
# 17.767831927247357
# 20.97044996449154
# 25.36815874929886
# 20.66484837073438
# 16.499395925304135
# 25.975233144624212
# 17.205390763642058
# 21.886059375322603
# 27.827620146171704
# 19.67124869463506
# 17.22400236653401
# 29.40578534720295
# 22.20007225026666
# 17.489728878236946
# 23.541782236496765
# 21.219003568855996
# 17.179606846316357
# 24.362286641400722
# 23.251005889793305
# 19.504120681103085
# 29.233184980238327
# 16.540459650593778
# 19.77206991822251
# 21.21669724661346
# 18.79381971071835
# 21.760276982571483
# 27.218823020366298
# 19.589244108037157
# 25.586479157940637
# 21.71362673188852
# 22.283766095768918
# 22.84883640116102
# 22.238542800086574
# 23.21361379933772
# 26.645762650662157
# 20.98260584850735
# 23.54501878794256
# 19.551321528563868
# 27.200586077247365
# 16.61803848970365
# 29.00470216455408
# 19.799210246778284
# 20.640522074553946
# 16.594741712625595
# 24.203217744943622
# 16.736880103488044
# 17.769082833926102
# 17.738468403754617
# 23.802073280721487
# 23.92900079325416
# 22.127287808924823
# 15.165119284353935
# 19.7614432192901
# 19.981987304547157
# 27.51699150883575
# 24.386811452878355
# 18.89517913085168
# 20.134429194972654
# 21.04191403973776
# 18.764113087397014
# 16.590078760011007
# 18.594498535570224
# 28.988432634247612
# 23.20421430633505
# 17.144105051086015
# 22.862913906780793
# 16.5
# 17.3

# %%
### bonus from the slides: Try to use an aggregate function like sum or avg on a field
### I dont think TinyFlux supports aggregate functions...you need to convert points results list into a DF first

# %% [markdown]
# ## Querying by Tag

# %%
# Search for a tag value
Tag = TagQuery()
tag_results = db.search(Tag.landscape_type == 'suburb')
print("\nTag Query Results:")
for x in tag_results:
    print(x)

### how would you approach this if the tag was not unique but existed in multiple measurements within the same database?
# Out:
# Tag Query Results:
# Point(time=2020-01-01T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:19.308678494144075)
# Point(time=2020-01-01T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature
00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:16.998915614206027)
# Point(time=2020-01-12T13:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:16.998915614206027)
# Point(time=2020-01-12T14:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.349010424950094)
# Point(time=2020-01-12T14:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.349010424950094)
# Point(time=2020-01-12T15:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.0734320156912)
# Point(time=2020-01-12T15:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.0734320156912)
# Point(time=2020-01-12T20:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:30.665166873281333)
# Point(time=2020-01-12T20:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:30.665166873281333)
# Point(time=2020-01-13T02:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.959388748213623)
# Point(time=2020-01-13T02:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.959388748213623)
# Point(time=2020-01-13T03:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.534995326705836)
# Point(time=2020-01-13T03:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.534995326705836)
# Point(time=2020-01-13T05:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.248010485105123)
# Point(time=2020-01-13T05:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.248010485105123)
# Point(time=2020-01-13T09:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.536497604383047)
# Point(time=2020-01-13T09:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.536497604383047)
# Point(time=2020-01-13T10:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.0643105941948)
# Point(time=2020-01-13T10:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.0643105941948)
# Point(time=2020-01-13T12:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.855024945389639)
# Point(time=2020-01-13T12:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.855024945389639)
# Point(time=2020-01-13T17:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:20.58663691654391)
# Point(time=2020-01-13T17:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:20.58663691654391)
# Point(time=2020-01-13T21:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.98903673783053)
# Point(time=2020-01-13T21:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:18.98903673783053)
# Point(time=2020-01-13T23:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:25.49388425993595)
# Point(time=2020-01-13T23:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:25.49388425993595)
# Point(time=2020-01-14T03:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.105019208163796)
# Point(time=2020-01-14T03:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.105019208163796)
# Point(time=2020-01-14T04:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:23.40976485647482)
# Point(time=2020-01-14T04:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:23.40976485647482)
# Point(time=2020-01-14T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.62083176244221)
# Point(time=2020-01-14T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.62083176244221)
# Point(time=2020-01-14T09:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:22.97578512718457)
# Point(time=2020-01-14T09:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:22.97578512718457)
# Point(time=2020-01-14T10:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.908896583832638)
# Point(time=2020-01-14T10:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.908896583832638)
# Point(time=2020-01-14T14:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:25.790554367500338)
# Point(time=2020-01-14T14:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:25.790554367500338)
# Point(time=2020-01-14T17:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:23.1417275463214)
# Point(time=2020-01-14T17:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:23.1417275463214)
# Point(time=2020-01-14T18:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.938766135765427)
# Point(time=2020-01-14T18:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.938766135765427)
# Point(time=2020-01-14T22:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:24.875598667088756)
# Point(time=2020-01-14T22:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:24.875598667088756)
# Point(time=2020-01-14T23:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.264713092489306)
# Point(time=2020-01-14T23:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.264713092489306)
# Point(time=2020-01-15T00:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.872514016037442)
# Point(time=2020-01-15T00:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.872514016037442)
# Point(time=2020-01-15T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:17.181377235980126)
# Point(time=2020-01-15T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:17.181377235980126)
# Point(time=2020-01-15T05:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:21.218436057459563)
# Point(time=2020-01-15T05:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:21.218436057459563)
# Point(time=2020-01-15T07:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.46528412314435)
# Point(time=2020-01-15T07:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.46528412314435)
# Point(time=2020-01-15T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:12.759578292513378)
# Point(time=2020-01-15T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:12.759578292513378)
# Point(time=2020-01-15T11:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:12.962681128117223)
# Point(time=2020-01-15T11:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:12.962681128117223)
# Point(time=2020-01-15T15:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:27.376781084747762)
# Point(time=2020-01-15T15:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:27.376781084747762)
# Point(time=2020-01-15T16:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature
00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.175382697099478)
# Point(time=2020-01-18T18:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:15.175382697099478)
# Point(time=2020-01-18T22:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:14.083707436671125)
# Point(time=2020-01-18T22:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:14.083707436671125)
# Point(time=2020-01-19T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:28.143077727856458)
# Point(time=2020-01-19T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:28.143077727856458)
# Point(time=2020-01-19T07:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.722261505516904)
# Point(time=2020-01-19T07:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.722261505516904)
# Point(time=2020-01-19T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:9.662789499800617)
# Point(time=2020-01-19T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:9.662789499800617)
# Point(time=2020-01-19T11:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.55439980243606)
# Point(time=2020-01-19T11:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.55439980243606)
# Point(time=2020-01-19T15:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:15.300601068363225)
# Point(time=2020-01-19T15:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:15.300601068363225)
# Point(time=2020-01-19T16:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.430665413316532)
# Point(time=2020-01-19T16:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.430665413316532)
# Point(time=2020-01-19T18:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.68660451363414)
# Point(time=2020-01-19T18:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:19.68660451363414)
# Point(time=2020-01-19T22:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.348711908137794)
# Point(time=2020-01-19T22:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.348711908137794)
# Point(time=2020-01-20T01:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:14.823788387903129)
# Point(time=2020-01-20T01:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:14.823788387903129)
# Point(time=2020-01-20T03:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:14.010610537055758)
# Point(time=2020-01-20T03:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:14.010610537055758)
# Point(time=2020-01-20T05:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.176317759858645)
# Point(time=2020-01-20T05:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.176317759858645)
# Point(time=2020-01-20T06:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.50137246003707)
# Point(time=2020-01-20T06:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.50137246003707)
# Point(time=2020-01-20T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.43835975154585)
# Point(time=2020-01-20T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.43835975154585)
# Point(time=2020-01-20T09:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.895152002333884)
# Point(time=2020-01-20T09:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.895152002333884)
# Point(time=2020-01-20T17:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:26.834371337222624)
# Point(time=2020-01-20T17:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:26.834371337222624)
# Point(time=2020-01-20T23:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:25.597874557172883)
# ...
# Point(time=2020-02-05T02:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:14.386389892188507)
# Point(time=2020-02-05T05:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:22.462256320040744)
# Point(time=2020-02-05T05:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:22.462256320040744)
# Point(time=2020-02-05T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:16.81130007874342)
# Point(time=2020-02-05T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:16.81130007874342)
# Point(time=2020-02-05T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.88429736787618)
# Point(time=2020-02-05T10:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.88429736787618)
# Point(time=2020-02-05T17:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:22.35707778193202)
# Point(time=2020-02-05T17:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:22.35707778193202)
# Point(time=2020-02-05T20:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:21.0146151042565)
# Point(time=2020-02-05T20:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:21.0146151042565)
# Point(time=2020-02-05T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:27.737526006650306)
# Point(time=2020-02-05T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:27.737526006650306)
# Point(time=2020-02-06T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:21.672283949935125)
# Point(time=2020-02-06T03:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:21.672283949935125)
# Point(time=2020-02-06T05:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:30.051022693831747)
# Point(time=2020-02-06T05:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:30.051022693831747)
# Point(time=2020-02-06T07:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.00851377730773)
# Point(time=2020-02-06T07:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:16.00851377730773)
# Point(time=2020-02-06T14:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.91788551963624)
# Point(time=2020-02-06T14:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.91788551963624)
# Point(time=2020-02-06T15:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:25.94196636724042)
# Point(time=2020-02-06T15:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:25.94196636724042)
# Point(time=2020-02-06T17:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.345656135398396)
# Point(time=2020-02-06T17:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.345656135398396)
# Point(time=2020-02-06T18:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.55280278740889)
# Point(time=2020-02-06T18:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:17.55280278740889)
# Point(time=2020-02-06T20:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:23.40945744813156)
# Point(time=2020-02-06T20:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:23.40945744813156)
# Point(time=2020-02-06T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.919640926629818)
# Point(time=2020-02-06T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.919640926629818)
# Point(time=2020-02-07T02:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.102410905986822)
# Point(time=2020-02-07T02:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:24.102410905986822)
# Point(time=2020-02-07T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:25.333373447945768)
# Point(time=2020-02-07T04:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:25.333373447945768)
# Point(time=2020-02-07T07:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:23.243549437948214)
# Point(time=2020-02-07T07:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:23.243549437948214)
# Point(time=2020-02-07T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.164409598415727)
# Point(time=2020-02-07T08:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:19.164409598415727)
# Point(time=2020-02-07T11:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:15.91532164506382)
# Point(time=2020-02-07T11:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:15.91532164506382)
# Point(time=2020-02-07T13:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.033305938363196)
# Point(time=2020-02-07T13:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.033305938363196)
# Point(time=2020-02-07T15:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:26.392259313036494)
# Point(time=2020-02-07T15:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:26.392259313036494)
# Point(time=2020-02-07T17:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.232182740780743)
# Point(time=2020-02-07T17:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:20.232182740780743)
# Point(time=2020-02-07T19:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.731267830136105)
# Point(time=2020-02-07T19:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.731267830136105)
# Point(time=2020-02-07T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.461108825234994)
# Point(time=2020-02-07T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:18.461108825234994)
# Point(time=2020-02-08T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.767831927247357)
# Point(time=2020-02-08T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.767831927247357)
# Point(time=2020-02-08T10:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.66484837073438)
# Point(time=2020-02-08T10:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.66484837073438)
# Point(time=2020-02-08T16:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:27.827620146171704)
# Point(time=2020-02-08T16:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:27.827620146171704)
# Point(time=2020-02-08T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.20007225026666)
# Point(time=2020-02-08T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.20007225026666)
# Point(time=2020-02-09T01:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.541782236496765)
# Point(time=2020-02-09T01:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:23.541782236496765)
# Point(time=2020-02-09T12:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:19.77206991822251)
# Point(time=2020-02-09T12:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:19.77206991822251)
# Point(time=2020-02-09T14:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:18.79381971071835)
# Point(time=2020-02-09T14:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:18.79381971071835)
# Point(time=2020-02-09T22:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:22.84883640116102)
# Point(time=2020-02-09T22:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:22.84883640116102)
# Point(time=2020-02-09T23:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.238542800086574)
# Point(time=2020-02-09T23:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:22.238542800086574)
# Point(time=2020-02-10T00:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:23.21361379933772)
# Point(time=2020-02-10T00:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:23.21361379933772)
# Point(time=2020-02-10T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:26.645762650662157)
# Point(time=2020-02-10T01:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:26.645762650662157)
# Point(time=2020-02-10T02:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.98260584850735)
# Point(time=2020-02-10T02:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.98260584850735)
# Point(time=2020-02-10T05:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:27.200586077247365)
# Point(time=2020-02-10T05:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:27.200586077247365)
# Point(time=2020-02-10T08:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.799210246778284)
# Point(time=2020-02-10T08:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.799210246778284)
# Point(time=2020-02-10T12:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:24.203217744943622)
# Point(time=2020-02-10T12:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:24.203217744943622)
# Point(time=2020-02-10T16:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.738468403754617)
# Point(time=2020-02-10T16:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:17.738468403754617)
# Point(time=2020-02-10T18:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:12.080485882571384)
# Point(time=2020-02-10T18:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:12.080485882571384)
# Point(time=2020-02-10T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:15.165119284353935)
# Point(time=2020-02-10T22:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:15.165119284353935)
# Point(time=2020-02-10T23:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.7614432192901)
# Point(time=2020-02-10T23:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:19.7614432192901)
# Point(time=2020-02-11T01:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:14.208176554037287)
# Point(time=2020-02-11T01:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:14.208176554037287)
# Point(time=2020-02-11T04:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:18.89517913085168)
# Point(time=2020-02-11T04:00:00+00:00, measurement=weather, tags=condition:cloudy; landscape_type:suburb, fields=temperature:18.89517913085168)
# Point(time=2020-02-11T05:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.134429194972654)
# Point(time=2020-02-11T05:00:00+00:00, measurement=weather, tags=condition:stormy; landscape_type:suburb, fields=temperature:20.134429194972654)
# Point(time=2020-02-11T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.04191403973776)
# Point(time=2020-02-11T06:00:00+00:00, measurement=weather, tags=condition:clear; landscape_type:suburb, fields=temperature:21.04191403973776)
# Point(time=2020-02-11T13:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:23.20421430633505)
# Point(time=2020-02-11T13:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:23.20421430633505)
# Point(time=2020-02-11T14:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.144105051086015)
# Point(time=2020-02-11T14:00:00+00:00, measurement=weather, tags=condition:rainy; landscape_type:suburb, fields=temperature:17.144105051086015)
# Point(time=2024-09-29T11:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:cloudy, fields=temperature:13.8)
# Point(time=2024-09-29T13:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:14.9)
# Point(time=2024-09-29T14:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:15.7)
# Point(time=2024-09-29T15:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:overcast, fields=temperature:16.5)
# Point(time=2024-09-29T15:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:overcast, fields=temperature:16.5)
# Point(time=2024-09-29T15:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:overcast, fields=temperature:16.5)
# Point(time=2024-09-29T15:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:overcast, fields=temperature:16.5)
# Point(time=2024-09-29T16:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:17.3)
# Point(time=2024-09-29T16:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:17.3)
# Point(time=2024-09-29T16:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:17.3)
# Point(time=2024-09-29T16:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:rainy, fields=temperature:17.3)

# %%
###  bonus from the slides: use a combination of grouping-by with an aggregate, like eg. count
### I dont think TinFlux supports  aggregate functions or even groupings...

# %%
### super bonus: how could you combine queries that have limitations on tags, field, and/or measurement?

Time = TimeQuery()
Tag = TagQuery()
q1 = Time > datetime(2024, 1, 1, tzinfo=timezone.utc)
q2 = Tag.condition == "cloudy"
qx = db.search(q1 & q2)

for x in qx:
    print(x)
# Out:
# Point(time=2024-09-29T11:00:00+00:00, measurement=_default, tags=landscape_type:suburb; condition:cloudy, fields=temperature:13.8)
